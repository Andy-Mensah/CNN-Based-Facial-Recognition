# %%
# !pip install dlib
# Out:
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for dlib
# Failed to build dlib
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [75 lines of output]
#   C:\Users\andre\AppData\Local\Temp\pip-install-30sm_w3p\dlib_c7979c6375f94345840c8b0bf659320a\setup.py:234: SyntaxWarning: invalid escape sequence '\('
#     major = re.findall("set\(CPACK_PACKAGE_VERSION_MAJOR.*\"(.*)\"", open(cmake_file).read())[0]
#   C:\Users\andre\AppData\Local\Temp\pip-install-30sm_w3p\dlib_c7979c6375f94345840c8b0bf659320a\setup.py:235: SyntaxWarning: invalid escape sequence '\('
#     minor = re.findall("set\(CPACK_PACKAGE_VERSION_MINOR.*\"(.*)\"", open(cmake_file).read())[0]
# ...
